# %% [markdown]
# # Lectura de ficheros de texto con Python pandas

# %%
import pandas as pd

# %% [markdown]
# pd.read_csv(filepath_or_buffer, sep=', ', delimiter=None, header='infer', names=None, index_col=None, usecols=None, squeeze=False, prefix=None, mangle_dupe_cols=True, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skipinitialspace=False, skiprows=None, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, skip_blank_lines=True, parse_dates=False, infer_datetime_format=False, keep_date_col=False, date_parser=None, dayfirst=False, iterator=False, chunksize=None, compression='infer', thousands=None, decimal=b'.', lineterminator=None, quotechar='"', quoting=0, escapechar=None, comment=None, encoding=None, dialect=None, tupleize_cols=None, error_bad_lines=True, warn_bad_lines=True, skipfooter=0, doublequote=True, delim_whitespace=False, low_memory=True, memory_map=False, float_precision=None)

# %%
#Poned el directorio donde os descargáis los datos
path = 'https://raw.githubusercontent.com/analisisydecision/intro_python_data_science/master/'
#path = "C:\\temp\\dataset\\"

# %%
df = pd.read_csv (path + 'index.csv')

# %% [markdown]
# Recomendable ejecutar siempre una simple vista

# %%
df.head()
# Out:
#    Creditability  Account Balance  Duration of Credit (month)  \
# 0              1                1                          18
# 1              1                1                           9
# 2              1                2                          12
# 3              1                1                          12
# 4              1                1                          12
#
#    Payment Status of Previous Credit  Purpose  Credit Amount  \
# 0                                  4        2           1049
# 1                                  4        0           2799
# 2                                  2        9            841
# 3                                  4        0           2122
# 4                                  4        0           2171
#
#    Value Savings/Stocks  Length of current employment  Instalment per cent  \
# 0                     1                             2                    4
# ...

# %%
df.shape
# Out:
# (1000, 21)

# %% [markdown]
# Se observa que por defecto el separador de la función read_csv es la , Si tenemos otro separador producirá resultados inesperados.

# %%
df = pd.read_csv (path + 'bank-additional-full.csv')
df.head()
# Out:
#   age;"job";"marital";"education";"default";"housing";"loan";"contact";"month";"day_of_week";"duration";"campaign";"pdays";"previous";"poutcome";"emp.var.rate";"cons.price.idx";"cons.conf.idx";"euribor3m";"nr.employed";"y"
# 0  56;"housemaid";"married";"basic.4y";"no";"no";...
# 1  57;"services";"married";"high.school";"unknown...
# 2  37;"services";"married";"high.school";"no";"ye...
# 3  40;"admin.";"married";"basic.6y";"no";"no";"no...
# 4  56;"services";"married";"high.school";"no";"no...

# %% [markdown]
# Vemos que no tiene sentido la lectura, es evidente que el separador es ';'

# %%
df = pd.read_csv (path + 'bank-additional-full.csv', sep = ';')
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
df.shape
# Out:
# (41188, 21)

# %% [markdown]
# Estamos trabajando con pocos registros, se torna muy importante hacer una lectura parcial del archivo de texto para comprobar como está funcionando nuestra importación.

# %%
df = pd.read_csv (path + 'bank-additional-full.csv', sep = ';', nrows= 200)
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
df.shape
# Out:
# (200, 21)

# %% [markdown]
# En ocasiones tenemos ficheros de texto enormes y necesitamos leerlos por trozos para que no se llene la memoria. En este caso vamos a leer el conjunto de datos por meses y seleccionar 2 meses. Esto será lo que llamaremos lectura por chunks.

# %%
meses = ['may', 'jul']

df = pd.DataFrame()
for trozo in pd.read_csv(path + 'bank-additional-full.csv', sep=';',
                             chunksize=1000):
    df = pd.concat([df,trozo[trozo['month'].isin(meses)]])

df.month.value_counts()
# Out:
# may    13769
# jul     7174
# Name: month, dtype: int64

# %%
df.shape
# Out:
# (20943, 21)

# %%
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
df['month'].value_counts()
# Out:
# may    13769
# jul     7174
# Name: month, dtype: int64

# %% [markdown]
# Con chunksize estamos leyendo el archivo csv en trozos (chunks) de 1000 en 1000 y nos quedamos sólo con aquellos que cumplan un determinado requisito, en este caso que el campo month sea 'may' o 'jul'. E incluso se puede leer el csv extrayendo una muestra aleatoria mientras leéis el fichero por partes y no sobre pasar la memoria:

# %%
df2 = pd.DataFrame()
for trozo in pd.read_csv(path + 'bank-additional-full.csv', sep=';',
                             chunksize=1000):
    df2 = pd.concat([df2,trozo.sample(frac=0.25)])
df2.shape
# Out:
# (10297, 21)

# %%
df2.month.value_counts()
# Out:
# may    3431
# jul    1794
# aug    1561
# jun    1316
# nov    1021
# apr     687
# oct     176
# sep     140
# mar     129
# dec      42
# Name: month, dtype: int64

# %% [markdown]
# En este último ejemplo se realiza una lectura por chunks seleccionando de forma aleatoria el 25% de los registros, con ello podemos ahorrar mucha memoria.
#
# Un notebook no tiene un navegador de objetos como los IDE más habituales por ello es aconsejable ejecutar <code>whos</code>

# %%
whos
# Out:
# Variable   Type         Data/Info
# ---------------------------------
# df         DataFrame           age            job<...>[20943 rows x 21 columns]
# df2        DataFrame           age           job <...>[10297 rows x 21 columns]
# meses      list         n=2
# np         module       <module 'numpy' from '/Us<...>kages/numpy/__init__.py'>
# path       str          https://raw.githubusercon<...>thon_data_science/master/
# pd         module       <module 'pandas' from '/U<...>ages/pandas/__init__.py'>
# trozo      DataFrame           age          job  <...>\n[188 rows x 21 columns]
